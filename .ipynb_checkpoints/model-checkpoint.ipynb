# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('./iris.data',header=0,names=['sepal_length','sepal_width','petal_length','petal_width','class'])

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
X=df.drop('class',1).to_numpy()
Y=df['class'].to_numpy()

# %%
print(X[0])
print(Y[0])
# Out:
# [4.9 3.  1.4 0.2]
# Iris-setosa

# %%
from sklearn.cluster import KMeans

K=10

iner={}
labels={}
for k in range(1,K):
    kmeans=KMeans(n_clusters=k).fit(X)
    
    labels[k]=kmeans.labels_
    
    iner[k]=kmeans.inertia_

# %%
plt.figure()
plt.plot(list(iner.keys()), list(iner.values()))
plt.xlabel("Number of cluster")
plt.ylabel("inertia")
plt.show()

# %%
df_pred=df
df_pred['class']=labels[4]


import seaborn as sns

sns.pairplot(df_pred,hue='class',palette='muted')
